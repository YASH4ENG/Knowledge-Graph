# %%
import requests
import numpy as np
# !pip install "tensorflow>=1.14.0,<2.0"
# !pip install "tensorflow-gpu>=1.14.0,<2.0"
# !pip install  ampligraph

# %%
import ampligraph
import numpy as np
ampligraph.__version__
import pandas as pd
from ampligraph.datasets import load_from_ntriples
from ampligraph.datasets import load_from_csv

# %%
Y=load_from_csv('/content','1500data.csv',sep=',',add_reciprocal_rels=False)

# %%
print(Y)
# Out:
# [['Common symptoms' 'include' 'fever']
#  ['Management' 'involves' 'treatment']
#  ['The World Health Organization' 'declared' 'outbreak']
#  ...
#  ['Helmand' 'had' 'two']
#  ['the Ministry of Public Health' 'confirmed' '106 new cases']
#  ['Baghlan' 'had' 'six']]

# %%
Y.shape
# Out:
# (1459, 3)

# %%
entities = np.unique(np.concatenate([Y[:, 0], Y[:, 2]]))
entities.size
# Out:
# 2370

# %%
relations = np.unique(Y[:, 1])
relations.size
# Out:
# 616

# %%
from ampligraph.evaluation import train_test_split_no_unseen 

Y_train, Y_test = train_test_split_no_unseen(Y, test_size=55)

# %%
print('Train set size: ', Y_train.shape)
print('Test set size: ', Y_test.shape)
# Out:
# Train set size:  (1404, 3)
# Test set size:  (55, 3)

# %%
print(Y_train[:200])
# Out:
# [['Common symptoms' 'include' 'fever']
#  ['Management' 'involves' 'treatment']
#  ['The World Health Organization' 'declared' 'outbreak']
#  ['minority' 'develop' 'noticeable symptoms']
#  ['Cardiovascular complications' 'include' 'heart failure']
#  ['Sputum' 'carry' 'large amounts']
#  ['indicative' 'suggest' 'underlying immunopathology']
#  ['people' 'have' 'classical serum biomarkers']
#  ['The US Food and Drug Administration' 'approved' 'test']
#  ['guidelines' 'recommend' 'medication']
#  ['Face coverings' 'limit' 'volume']
#  ['the United States Environmental Protection Agency' 'maintains' 'list']
#  ['Intensivists' 'compiled' 'treatment recommendations']
#  ['availability' 'affect' 'mortality']
#  ['study' 'reported' 'earliest date']
#  ['Official publications' 'reported' 'earliest onset']
#  ['Wuhan Central Hospital' 'sent'
#   'bronchoalveolar lavage fluid BAL sample']
#  ['the National Health Commission of China' 'issued' 'notice']
#  ['China' 'reported' 'nearly 140 new cases']
#  ['Italy' 'overtook' 'China']
#  ['the United States' 'overtaken' 'China']
#  ['ratio' 'reflects' 'number']
#  ['the World Health Organization' 'reported' 'estimates']
#  ['random antibody testing' 'suggested' 'national IFR']
#  ['Early reviews' 'showed' 'greater impact']
#  ['Similar issues' 'affect' 'Native American and Latino communities']
#  ['pandemic' 'had' 'impacts']
#  ['people' 'is' 'timely treatment']
#  ['Shortages' 'impacted' 'people']
#  ['pandemic' 'impacted' 'mental health']
#  ['the World Health Organization' 'suspended' 'hydroxychloroquine']
#  ['the World Health Organization' 'enrolled' '3,500 patients']
#  ['agencies' 'is' 'vaccine candidates']
#  ['Viral vectors' 'include' 'Chimpanzee Adenovirus']
#  ['Seven trials' 'evaluating' 'approved treatments']
#  ['the United States Food and Drug Administration' 'is'
#   'emergency use authorization']
#  ['studies' 'are' 'little improvement']
#  ['law' 'defined' 'minimal restriction']
#  ['Gresik Regency' 'implemented in' 'PSBB']
#  ['local city government' 'submitted' 'PSBB']
#  ['PSBB Makassar' 'takes' 'effect']
#  ['Trump administration' 'put' 'sanctions']
#  ['Russia' 'claim' 'oil war']
#  ['Russian Saudi officials' 'confirmed that' 'existence']
#  ['Saudi Arabia' 'announced' 'unexpected price discounts']
#  ['stock markets' 'reported' 'major losses']
#  ['OPEC' 'expected' 'demand']
#  ['OPEC' 'requested' 'Mexico']
#  ['Cushing' 'reached' 'nearly 64 million barrels']
#  ['Low oil price' 'put' 'pressure']
#  ['Saudi Aramco' 'announced' 'cut']
#  ['stock markets' 'experienced' 'drops']
#  ['multiple oil producers' 'cut' 'drilling']
#  ['The United Arab Emirates' 'announced' 'increase']
#  ['Nizamuddin Markaz calendar' 'shows' 'three events']
#  ['Aalmi Mashwara' 'attracted' '1500 persons']
#  ['Andhra Pradesh gathering' 'attracted' 'similar numbers']
#  ['tehsildar' 'visited' 'Markaz']
#  ['elected government' 'ordered' 'thermal screening']
#  ['elected government' 'ordered' 'closure']
#  ['Maharashtra' 'traced' '1,325, 1,064 and 800 attendees']
#  ['Gujarat Police' 'reported that' 'more than 500 foreign preachers']
#  ['Security agencies' 'traced' 'link']
#  ['two Thai Nationals' 'attended' 'congregation']
#  ['donors' 'broke' 'donors']
#  ['female Tablighi Jamaat members' 'donated' 'female Jamaat members']
#  ['at least three mosques' 'included' 'the Jama Masjid Moazzampura']
#  ['man' 'hanged' 'man']
#  ['social media users' 'projected' 'Muslims']
#  ['Muslim students' 'faced' 'discrimination']
#  ['Tablighi Jamaat' 'See also.2020' 'hotspot']
#  ['protests' 'made' 'international news']
#  ['speakers' 'organized by' 'three Republican state legislators']
#  ['# ReOpenAmerica Planning Guide".Protesters' 'opposed' 'orders']
#  ['Protesters' 'included' 'mainstream Republicans']
#  ['Michigan' 'had' 'at least 28,059 confirmed cases']
#  ['Governor' 'extended' 'state']
#  ['small group' 'patrolled' 'streets']
#  ['The Libertarian Party of Connecticut' 'organized' 'event']
#  ['New Hampshire' 'On' 'businesses']
#  ['scores' 'blared' 'horns']
#  ['protesters' 'ignored' 'social distancing protocols']
#  ['group' 'did' 'squats']
#  ['ReOpen Maryland' 'organized' 'driving protest']
#  ['Suffolk County' 'held in' 'rally']
#  ['leader' 'described' 'leader']
#  ['a few dozen protesters' 'demanded' 'reopening']
#  ['only three' 'planned for' 'large crowds']
#  ['2000 protesters' 'join' 'LibertyFest anti-lockdown rally']
#  ['Several hundred protesters' 'assembled at' 'Disobey Idaho']
#  ['Small protests' 'took' 'place']
#  ['The Kitsap County Republican Party' 'coordinated' 'event']
#  ['Speakers' 'included' 'three Republican state legislators']
#  ['Governor Jay Inslee' 'accused' 'president']
#  ['president statements' '" tweets' 'illegal dangerous acts']
#  ['president' 'putting'
#   'millions of people in danger of contracting COVID-19']
#  ['lawmakers' 'condemned' 'Small protests']
#  ['ACE2 protein' 'contains' 'N terminal peptidase M2 domain']
#  ['ACE2' 'cleave' 'number']
#  ['ACE2' 'regulates' 'membrane trafficking']
#  ['interaction' 'induces' 'drop']
#  ['multiple professional societies' 'recommended'
#   'continuing standard ACE inhibitor']
#  ['global markets' 'reported' 'severe contractions']
#  ['global stocks' 'saw' 'downturn']
#  ['Singaporean Finance Minister Heng Swee Keat' 'announced'
#   '4.5 billion fiscal stimulus program']
#  ['Indonesian Finance Minister Sri Mulyani' 'announced'
#   '742 million fiscal stimulus program']
#  ['Outgoing Malaysian Prime Minister Mahathir Mohamad' 'announced'
#   'RM20 billion fiscal stimulus package']
#  ['South Korean Finance Minister Hong Nam-ki' 'announced'
#   '₩11.7 trillion 9.8 billion fiscal stimulus program']
#  ['U.S. President Donald Trump' 'signed into' 'emergency appropriations']
#  ['biggest discounts' 'targeted' 'Russian oil customers']
#  ['NASDAQ Composite' 'lost over 620 points' '620 points']
#  ["Canada's S&P/TSX Composite Index" 'finished' 'the day']
#  ["Brazil's IBOVESPA" 'gave up' '12%']
#  ["Canada's S&P/TSX Composite Index" 'lost' '3%']
#  ['combination' 'created' 'killer cocktail']
#  ['Australian Prime Minister Scott Morrison' 'announced' 'A$2.4 billion']
#  ['Indonesian Finance Minister Sri Mulyani' 'announced' 'tax relief']
#  ['Italian Prime Minister Giuseppe Conte' 'announced'
#   '€ 25 billion 28 billion fiscal stimulus']
#  ['U.S. President Donald Trump' 'gave' 'public address']
#  ['U.S. President Donald Trump' 'announced' 'temporary 30-day travel ban']
#  ['temporary 30-day travel ban' 'excluded' 'the United Kingdom']
#  ['U.S. President Donald Trump' 'attributed to' '30-day travel ban']
#  ['Australian Prime Minister Scott Morrison' 'announced'
#   '17.6 billion fiscal stimulus package']
#  ['The Bank of Mexico' 'auctioned' '$1.78 billion foreign exchange spots']
#  ['peso' 'set' 'low']
#  ['The Bank of Mexico' 'announced' 'an additional 50 basis point']
#  ['The Bank of Mexico Japan' 'announced' '¥200 billion']
#  ['The Bank of Mexico Canada' 'announced' 'C$7.5 billion']
#  ['The Bank of Mexico' 'conducted' 'billion']
#  ['The Bank of Mexico Japan' 'conducted' '¥120 billion']
#  ['New Zealand Finance Minister Grant Robertson' 'announced'
#   'NZ$12.1 billion fiscal stimulus program']
#  ['The Federal Reserve' 'established' 'additional lending facility']
#  ['The Bank of Mexico Japan' 'conducted' '¥1.3 trillion']
#  ['Bank Indonesia' 'cut' 'Bank Indonesia repo rate']
#  ['Chilean President Sebastián Piñera' 'announced'
#   '11.7 billion fiscal stimulus package']
#  ['The Bank of Mexico' 'opened' '€ 24 billion foreign exchange swap line']
#  ['The Bank of Mexico' 'announced' 'Ft74.5 billion']
#  ['U.S. Senate' 'passed' '11.7 billion fiscal stimulus package']
#  ['The Reserve Bank of New Zealand' 'announced' 'million']
#  ['The Bank of Mexico' 'announced' 'quantitative easing program']
#  ['Singaporean Finance Minister Heng Swee Keat' 'announced'
#   'second fiscal stimulus package']
#  ['Indian Finance Minister Nirmala Sitharaman' 'announced'
#   '23 billion fiscal stimulus package']
#  ['The U.S. House of Representatives' 'passed'
#   '23 billion fiscal stimulus packagea 23 billion fiscal stimulus package']
#  ['The Bank of Mexico' 'announced' 'an additional €750 billion']
#  ['Malaysian Prime Minister Muhyiddin Yassin' 'announced'
#   'RM250 billion 57 billion fiscal stimulus package']
#  ['government' 'announced'
#   '₽ 150 billion 1.92 billion credit line program']
#  ['app' 'reached' 'more than 100 million installs']
#  ['central government' 'gave' 'announcement']
#  ['the Airport Authority of India' 'issued' 'stating']
#  ['Government' 'launched' 'bug bounty program']
#  ['mismatch' 'cause' 'potentially fatal adverse reaction']
#  ['Karl Landsteiner' 'received'
#   'the Nobel Prize in Physiology or Medicine']
#  ['humans' 'believed that' 'similar blood']
#  ['Czech serologist Jan Janský' 'introduced' 'blood type classification']
#  ['Czech serologist Jan Janský' 'used' 'numerical']
#  ['systems' 'created' 'confusion']
#  ['Felix Bernstein' 'demonstrated'
#   'correct blood group inheritance pattern']
#  ['text' 'summarizes' 'outcomes']
#  ['common O alleles' 'share' 'common O alleles']
#  ['premature stop' 'codon' 'results']
#  ['four main lineages' 'comprise' 'following alleles']
#  ['carbohydrate molecules' 'have' 'roles']
#  ['non - O group AB B individuals' 'have' '14 % reduced risk']
#  ['ABO' 'hemolytic' 'disease']
#  ['baby' 'produced' 'ABO hemolytic disease']
#  ['genome wide association study' 'identified' 'variants']
#  ['removal' 'address' 'problem']
#  ['ABO' 'explained' 'YouTube educational video']
#  ['causes' 'include' 'asthma']
#  ['Cough medicine' 'has' 'little support']
#  ['Tentative evidence' 'supports' 'honey']
#  ['about 6%' 'affected' 'at least one episode']
#  ['More than 10 million people' 'visit' 'doctor']
#  ['illness' 'have' 'shortness']
#  ['Upper respiratory tract infections' 'precede' 'acute bronchitis']
#  ['Typical viruses' 'include' 'respiratory syncytial virus']
#  ['physical examination' 'reveal' 'decreased intensity']
#  ['Dullness' 'suggest' 'disease extension']
#  ['recommendations' 'include' 'rest']
#  ['Evidence' 'support' 'general use']
#  ['Acute bronchitis' 'lasts' 'a few days or weeks']
#  ['infections' 'found in' '75%']
#  ['diagnostic criteria' 'include' 'increase']
#  ['Hemoptysis' 'indicate' 'potentially fatal medical conditions']
#  ['Inhaled bronchodilators' 'open up' 'airways']
#  ['antibiotics' 'treat' 'exacerbations']
#  ['Lipid soluble antibiotics' 'penetrate' 'lung tissue']
#  ['course' 'speed up' 'recovery']
#  ['Severe exacerbations' 'require' 'hospital care']
#  ['typical COPD patient' 'averages' 'two to three AECB episodes']
#  ['Chronic infection' 'keep' 'pad']
#  ['viruses' 'cause' 'dramatic enlargement']
#  ['Physical examination' 'provide' 'clues']
#  ['Certain medication classes' 'damage' 'tubular cells']
#  ['50–100 ml' 'suggests' 'neurogenic bladder dysfunction']
#  ['Indications' 'include' 'following:.Unexplained AKI']
#  ['CT scan' 'demonstrate' 'bladder distension']
#  ['myriad causes' 'require' 'specific therapies']
#  ['systematic review' 'demonstrated' 'difference']
#  ['Metabolic acidosis' 'require' 'medical treatment']]

# %%
from ampligraph.latent_features import DistMult

# %%
model = DistMult(batches_count=10, 
                seed=0, 
                epochs=20, 
                k=10, 
                eta=10,
                optimizer='adam', 
                optimizer_params={'lr':1e-3},
                loss='multiclass_nll', 
                regularizer='LP', 
                regularizer_params={'p':3, 'lambda':1e-5}, 
                verbose=True)

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

model.fit(Y_train, early_stopping = False)
# Out:
# Average Loss:   2.373535: 100%|██████████| 20/20 [00:00<00:00, 32.16epoch/s]

# %%
model.get_embeddings(['The World Health Organization','outbreak'], embedding_type='entity')
# Out:
# array([[ 0.02188077,  0.16830604, -0.16845378,  0.14712408,  0.0920139 ,
#          0.14495565,  0.16449702,  0.16962336, -0.12333542, -0.12468348],
#        [-0.02864343, -0.1320078 ,  0.09050266, -0.08716419, -0.08889943,
#          0.12126279,  0.10065684, -0.1495471 ,  0.06595367, -0.12121323]],
#       dtype=float32)

# %%
model.get_embeddings(['common symptoms','cough'], embedding_type='entity')
# Out:
# array([[ 0.03686009,  0.12477501,  0.15571064, -0.08261333,  0.0190071 ,
#          0.1030189 , -0.05289743,  0.13939205, -0.12855546, -0.06819809],
#        [-0.1344412 ,  0.05155814,  0.09203613,  0.09430119,  0.15649106,
#         -0.09254248, -0.11649413, -0.10214522,  0.0510114 , -0.13438725]],
#       dtype=float32)

# %%
positives_filter = Y

# %%
from ampligraph.latent_features import save_model, restore_model

# %%
save_model(model, './covid_model.pkl')

# %%
from ampligraph.evaluation import evaluate_performance

# %%
from ampligraph.discovery import find_duplicates

# %%
entities = np.unique(Y_train[:, 2])
dups, _ = find_duplicates(entities, model, mode='entity', tolerance=0.4)
print(list(dups)[:3])
# Out:
# [frozenset({'large amounts', '€ 25 billion 28 billion fiscal stimulus', 'bevacizumab indication', 'free prizes', 'fluid filled intestines', 'face mask production', 'billion', 'outpatient use', 'origins', 'blood type classification', 'seizures', 'the Solidarity Response Fund', 'severe heart block', 'low blood pressure', 'benefits', '144 men', 'Turner Prize', 'flights', 'different potential therapies', 'runny stuffy nose', 'supportive evidence', 'Questions', 'page memorandum', 'expedition', 'pressure', 'deployment', 'HCoV-OC43 and', 'Tamil', 'Microbiology Text page', 'drugs', 'consists', 'bacterial spores', 'hospital care', 'approximately 85%', 'particular', 'specialised Pathogen Genomics Intelligence Institute', 'potentially fatal medical conditions', 'conspicuous collar', 'medications', 'story', 'log entry', 'little improvement', 'numerous potentially effects', 'injuries', 'emergency use authorization', 'declaration', 'Caribbean diaspora', 'nose bleeds', 'branching associated aerated lung parenchyma', 'construction', 'naval nuclear power training program', 'second stage', 'links', 'ABO hemolytic disease', '62.5 per cent', 'more than 120,804 confirmed cases', 'respiratory illnesses', 'high levels', 'newly formed peptide bond', 'Nocardia infections', '50 % reduction', 'demand', 'abnormalities', 'little CRP response', 'Prevention', 'signals', 'good sensitivity', 'NZ$12.1 billion fiscal stimulus program', "Hadrian's Wall", 'occupation', 'ID codes', 'earliest date', 'the Mississippi River', 'ArcGIS Explorer', 'increased risks', 'emergency appropriations', 'substantial strides', 'three of the original nine patents on the computer on which all PCs', 'words', 'Cultural Threat', 'outbreaks', 'uncomfortable respiratory reactions', 'oil war', 'orders', 'older patients', 'timely treatment', 'Urdu', 'T2', 'term', 'impact', 'premature deaths', '1.Middle East respiratory syndrome-related coronavirus', 'hydroxychloroquine', 'suicide', '65%', 'relationship', 'at least one case', 'continuing standard ACE inhibitor', 'nearly 140 new cases', 'admission', 'advanced tertiary economy', 'copper', 'diet changes', 'SABA', 'rates', 'contraindications', 'two factors', 'captives', 'clues', 'four abandoned brown bear cubs', 'congregation', 'normal cell structures', 'gastrointestinal distress', 'women volleyball team', 'international news coverage', 'concomitant UTI', 'smog type formation', 'permanent discontinue', 'million', 'open air sports', 'bad breath', "Imtiaz Habib's Black Lives", 'AZA Exhibit Award', 'general distrust', 'longest tongue', 'blood brain barrier', 'regulations', 'account local understandings', 'an additional 50 basis point', 'unprecedented severe rebuke', 'consciousness', 'efficacy', 'highest death rate', 'body immune system', 'activities', 'realization', 'significant role', 'more than 80%', 'Gram positive bacteria', 'Nightingale', 'three extensions', 'exceptional success', 'Islam', 'sudden arterial hypoxemia', 'turn', 'employees', 'pre - existing health conditions', 'tigers', 'dissemination', 'bug bounty program', 'shortness', 'wines', 'ingrowth', 'sizable immigrant populations', 'allergic symptoms', 'diagnosis', 'N terminal peptidase M2 domain', 'about 2% to 3%', 'pan-Africanism', 'severe respiratory symptoms', 'pad', 'penetration', 'Run', 'cut', 'localized findings', '620 points', 'estimation', 'alternative diagnosis', '627 in the PB2 protein', '15 acres', 'adenoviruses', 'fifty new cases', 'longer lifespan', 'UK', 'cysteine glutamic acid', 'dead neurons', 'underlying immunopathology', '106 new cases', 'almost 20%', 'PSBB', 'average European ancestry', 'product', 'frescoes', 'different proteins', 'one new recovery', 'new case', '22 species', 'waste products', 'two live adult Komodo dragons', 'adenocarcinoma', 'pneumonia acute respiratory distress syndrome', 'fast track approval', 'crop yields', 'one type', 'multi - user editing', 'opacities', 'set', 'Pteropodidae', 'following:.Lungs', 'great deal', 'specific therapies', 'connection', ...

# %%
from ampligraph.discovery import query_topn

# %%
query_topn(model, top_n=5,
            head=None, relation='include', tail='cough',
           ents_to_consider=None, rels_to_consider=None)
# Out:
# (array([['people', 'include', 'cough'],
#         ['place', 'include', 'cough'],
#         ['aerosolized tobramycin', 'include', 'cough'],
#         ['Surgery', 'include', 'cough'],
#         ['Symptom', 'include', 'cough']], dtype='<U153'),
#  array([0.03273855, 0.03041483, 0.02913952, 0.02884051, 0.02759999],
#        dtype=float32))

# %%
ranks = evaluate_performance(Y_test, 
                             model=model, 
                             filter_triples=positives_filter,   # Corruption strategy filter defined above 
                             use_default_protocol=True, # corrupt subj and obj separately while evaluating
                             verbose=True)
# Out:
# WARNING - DeprecationWarning: use_default_protocol will be removed in future. Please use corrupt_side argument instead.
# 100%|██████████| 55/55 [00:00<00:00, 441.47it/s]

# %%
from ampligraph.evaluation import mr_score, mrr_score, hits_at_n_score
mr = mr_score(ranks)
mrr = mrr_score(ranks)
print("MRR: %.2f" % (mrr))
print("MR: %.2f" % (mr))
hits_10 = hits_at_n_score(ranks, n=10)
print("Hits@10: %.2f" % (hits_10))
hits_3 = hits_at_n_score(ranks, n=3)
print("Hits@3: %.2f" % (hits_3))
hits_1 = hits_at_n_score(ranks, n=1)
print("Hits@1: %.2f" % (hits_1))
# Out:
# MRR: 0.02
# MR: 1278.19
# Hits@10: 0.04
# Hits@3: 0.01
# Hits@1: 0.01

# %%
from ampligraph.utils import create_tensorboard_visualizations

# %%
create_tensorboard_visualizations(model,r"./")

# %%
X_unseen = np.array([
    ['guidelines', 'recommend', 'medication'],
  ['black musician', 'wears', 'royal livery'],
   ['Common effects', 'include', 'chest infections'],
 #   ['pandemic', 'include', 'global social economic disruption']

])

# %%
unseen_filter = np.array(list({tuple(i) for i in np.vstack((positives_filter, X_unseen))}))

# %%
ranks_unseen = evaluate_performance(
    X_unseen, 
    model=model, 
    filter_triples=unseen_filter,   # Corruption strategy filter defined above 
    corrupt_side = 's+o',
    use_default_protocol=False, # corrupt subj and obj separately while evaluating
    verbose=True
)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 38.24it/s]

# %%
scores = model.predict(X_unseen)

# %%
from scipy.special import expit
probs = expit(scores)

# %%
pd.DataFrame(list(zip([' '.join(x) for x in X_unseen], 
                      ranks_unseen, 
                      np.squeeze(scores),
                      np.squeeze(probs))), 
             columns=['statement', 'rank', 'score', 'prob']).sort_values("score")
# Out:
#                                  statement  rank     score      prob
# 2  Common effects include chest infections  4381 -0.014421  0.496395
# 1        black musician wears royal livery    11  0.008373  0.502093
# 0          guidelines recommend medication     7  0.018678  0.504669
